# %% [markdown]
# <a href="https://colab.research.google.com/github/FernandoCutire/-op-data-pipeline/blob/master/docs/tutorials/getting-started/getting-started.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Getting Started with the SDK  <a href="https://colab.research.google.com/github/mostly-ai/mostlyai/blob/main/docs/tutorials/quick-start/quick-start.ipynb" target="_blank"><img src="https://img.shields.io/badge/Open%20in-Colab-blue?logo=google-colab" alt="Run on Colab"></a>
#
# In this notebook, we take our first steps with the SDK by training a basic single-table generator, to then probe it for new synthetic samples.
#
# Note, that the chosen dataset is for demo purposes and intentionally very small to make this tutorial run fast. Expect significantly higher quality in case of more training samples. See the other tutorials for reference.

# %%
# Install SDK in CLIENT mode
# !uv pip install -U mostlyai
# Or install in LOCAL mode
# !uv pip install -U 'mostlyai[local]'
# Note: Restart kernel session after installation!
# Out:
# Streaming output truncated to the last 5000 lines.
# fonttools  ------------------------------ 888.46 KiB/4.71 MiB
# xgrammar   ------------------------------ 848.00 KiB/5.56 MiB
# matplotlib ------------------------------ 361.81 KiB/8.21 MiB
# scikit-learn ------------------------------ 812.57 KiB/12.28 MiB
# pandas     ------------------------------ 316.44 KiB/12.45 MiB
# botocore   ------------------------------ 525.84 KiB/12.72 MiB
# ⠦ Preparing packages... (20/60)
# boto3      ------------------------------ 108.58 KiB/136.08 KiB
# azure-identity ------------------------------ 174.19 KiB/181.74 KiB
# google-auth ------------------------------ 206.61 KiB/211.07 KiB
# opacus     ------------------------------ 95.45 KiB/248.40 KiB
# azure-storage-file-datalake ------------------------------ 256.00 KiB/257.79 KiB
# protobuf   ------------------------------ 300.28 KiB/313.54 KiB
# narwhals   ------------------------------ 222.88 KiB/349.64 KiB
# azure-storage-blob ------------------------------ 298.51 KiB/397.45 KiB
# datasets   ------------------------------ 302.88 KiB/480.03 KiB
# pynacl     ------------------------------ 815.41 KiB/836.60 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 589.63 KiB/863.02 KiB
# setuptools ------------------------------ 188.69 KiB/1.15 MiB
# aiohttp    ------------------------------ 892.66 KiB/1.65 MiB
# cryptography ------------------------------ 892.74 KiB/4.26 MiB
# hf-xet     ------------------------------ 961.69 KiB/4.60 MiB
# fonttools  ------------------------------ 934.52 KiB/4.71 MiB
# xgrammar   ------------------------------ 912.00 KiB/5.56 MiB
# matplotlib ------------------------------ 361.81 KiB/8.21 MiB
# scikit-learn ------------------------------ 812.57 KiB/12.28 MiB
# pandas     ------------------------------ 348.44 KiB/12.45 MiB
# botocore   ------------------------------ 525.84 KiB/12.72 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 920.56 KiB/13.17 MiB
# ⠧ Preparing packages... (26/60)
# boto3      ------------------------------ 108.58 KiB/136.08 KiB
# azure-identity ------------------------------ 174.19 KiB/181.74 KiB
# google-auth ------------------------------ 206.61 KiB/211.07 KiB
# opacus     ------------------------------ 95.45 KiB/248.40 KiB
# azure-storage-file-datalake ------------------------------ 256.00 KiB/257.79 KiB
# protobuf   ------------------------------ 300.28 KiB/313.54 KiB
# narwhals   ------------------------------ 222.88 KiB/349.64 KiB
# azure-storage-blob ------------------------------ 298.51 KiB/397.45 KiB
# datasets   ------------------------------ 302.88 KiB/480.03 KiB
# pynacl     ------------------------------ 815.41 KiB/836.60 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 605.63 KiB/863.02 KiB
# setuptools ------------------------------ 188.69 KiB/1.15 MiB
# aiohttp    ------------------------------ 908.66 KiB/1.65 MiB
# cryptography ------------------------------ 892.74 KiB/4.26 MiB
# hf-xet     ------------------------------ 1009.69 KiB/4.60 MiB
# fonttools  ------------------------------ 934.52 KiB/4.71 MiB
# xgrammar   ------------------------------ 912.00 KiB/5.56 MiB
# matplotlib ------------------------------ 361.81 KiB/8.21 MiB
# scikit-learn ------------------------------ 812.57 KiB/12.28 MiB
# pandas     ------------------------------ 348.44 KiB/12.45 MiB
# botocore   ------------------------------ 525.84 KiB/12.72 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 920.56 KiB/13.17 MiB
# ⠧ Preparing packages... (26/60)
# boto3      ------------------------------ 124.58 KiB/136.08 KiB
# azure-identity ------------------------------ 181.74 KiB/181.74 KiB
# google-auth ------------------------------ 206.61 KiB/211.07 KiB
# opacus     ------------------------------ 95.45 KiB/248.40 KiB
# protobuf   ------------------------------ 313.54 KiB/313.54 KiB
# narwhals   ------------------------------ 222.88 KiB/349.64 KiB
# azure-storage-blob ------------------------------ 314.51 KiB/397.45 KiB
# datasets   ------------------------------ 302.88 KiB/480.03 KiB
# pynacl     ------------------------------ 831.99 KiB/836.60 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 637.63 KiB/863.02 KiB
# setuptools ------------------------------ 188.69 KiB/1.15 MiB
# aiohttp    ------------------------------ 908.66 KiB/1.65 MiB
# cryptography ------------------------------ 940.74 KiB/4.26 MiB
# hf-xet     ------------------------------ 1009.69 KiB/4.60 MiB
# fonttools  ------------------------------ 979.56 KiB/4.71 MiB
# xgrammar   ------------------------------ 960.00 KiB/5.56 MiB
# matplotlib ------------------------------ 569.71 KiB/8.21 MiB
# scikit-learn ------------------------------ 812.57 KiB/12.28 MiB
# pandas     ------------------------------ 396.33 KiB/12.45 MiB
# botocore   ------------------------------ 525.84 KiB/12.72 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 963.56 KiB/13.17 MiB
# plotly     ------------------------------ 271.08 KiB/15.51 MiB
# ⠧ Preparing packages... (26/60)
# boto3      ------------------------------ 124.58 KiB/136.08 KiB
# azure-identity ------------------------------ 181.74 KiB/181.74 KiB
# google-auth ------------------------------ 206.61 KiB/211.07 KiB
# opacus     ------------------------------ 95.45 KiB/248.40 KiB
# protobuf   ------------------------------ 313.54 KiB/313.54 KiB
# narwhals   ------------------------------ 222.88 KiB/349.64 KiB
# azure-storage-blob ------------------------------ 314.51 KiB/397.45 KiB
# datasets   ------------------------------ 302.88 KiB/480.03 KiB
# pynacl     ------------------------------ 831.99 KiB/836.60 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 637.63 KiB/863.02 KiB
# setuptools ------------------------------ 188.69 KiB/1.15 MiB
# aiohttp    ------------------------------ 908.66 KiB/1.65 MiB
# cryptography ------------------------------ 940.74 KiB/4.26 MiB
# hf-xet     ------------------------------ 1009.69 KiB/4.60 MiB
# fonttools  ------------------------------ 979.56 KiB/4.71 MiB
# xgrammar   ------------------------------ 960.00 KiB/5.56 MiB
# matplotlib ------------------------------ 569.71 KiB/8.21 MiB
# scikit-learn ------------------------------ 812.57 KiB/12.28 MiB
# pandas     ------------------------------ 396.33 KiB/12.45 MiB
# botocore   ------------------------------ 525.84 KiB/12.72 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 963.56 KiB/13.17 MiB
# plotly     ------------------------------ 287.08 KiB/15.51 MiB
# ⠧ Preparing packages... (26/60)
# boto3      ------------------------------ 124.58 KiB/136.08 KiB
# google-auth ------------------------------ 206.61 KiB/211.07 KiB
# opacus     ------------------------------ 95.45 KiB/248.40 KiB
# protobuf   ------------------------------ 313.54 KiB/313.54 KiB
# narwhals   ------------------------------ 222.88 KiB/349.64 KiB
# azure-storage-blob ------------------------------ 314.51 KiB/397.45 KiB
# datasets   ------------------------------ 302.88 KiB/480.03 KiB
# pynacl     ------------------------------ 831.99 KiB/836.60 KiB
# nvidia-cuda-runtime-cu12 ------------------------------ 637.63 KiB/863.02 KiB
# setuptools ------------------------------ 188.69 KiB/1.15 MiB
# aiohttp    ------------------------------ 908.66 KiB/1.65 MiB
# cryptography ------------------------------ 940.74 KiB/4.26 MiB
# hf-xet     ------------------------------ 1009.69 KiB/4.60 MiB
# fonttools  ------------------------------ 979.56 KiB/4.71 MiB
# xgrammar   ------------------------------ 960.00 KiB/5.56 MiB
# matplotlib ------------------------------ 569.71 KiB/8.21 MiB
# scikit-learn ------------------------------ 812.57 KiB/12.28 MiB
# pandas     ------------------------------ 396.33 KiB/12.45 MiB
# botocore   ------------------------------ 557.84 KiB/12.72 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 963.56 KiB/13.17 MiB
# plotly     ------------------------------ 303.08 KiB/15.51 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 978.84 KiB/20.09 MiB
# ⠧ Preparing packages... (26/60)
# boto3      ------------------------------ 124.58 KiB/136.08 KiB
# google-auth ------------------------------ 206.61 KiB/211.07 KiB
# opacus     ------------------------------ 95.45 KiB/248.40 KiB
# protobuf   ------------------------------ 313.54 KiB/313.54 KiB
# narwhals   ------------------------------ 222.88 KiB/349.64 KiB
# azure-storage-blob ------------------------------ 314.51 KiB/397.45 KiB
# datasets   ------------------------------ 302.88 KiB/480.03 KiB
# pynacl     ------------------------------ 831.99 KiB/836.60 KiB
# setuptools ------------------------------ 188.69 KiB/1.15 MiB
# aiohttp    ------------------------------ 924.66 KiB/1.65 MiB
# cryptography ------------------------------ 940.74 KiB/4.26 MiB
# hf-xet     ------------------------------ 1009.69 KiB/4.60 MiB
# fonttools  ------------------------------ 979.56 KiB/4.71 MiB
# xgrammar   ------------------------------ 960.00 KiB/5.56 MiB
# matplotlib ------------------------------ 569.71 KiB/8.21 MiB
# scikit-learn ------------------------------ 812.57 KiB/12.28 MiB
# pandas     ------------------------------ 396.33 KiB/12.45 MiB
# botocore   ------------------------------ 557.84 KiB/12.72 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 963.56 KiB/13.17 MiB
# plotly     ------------------------------ 303.08 KiB/15.51 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 978.84 KiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 979.39 KiB/23.50 MiB
# ⠧ Preparing packages... (26/60)
# boto3      ------------------------------ 136.08 KiB/136.08 KiB
# google-auth ------------------------------ 206.61 KiB/211.07 KiB
# opacus     ------------------------------ 95.45 KiB/248.40 KiB
# protobuf   ------------------------------ 313.54 KiB/313.54 KiB
# narwhals   ------------------------------ 222.88 KiB/349.64 KiB
# azure-storage-blob ------------------------------ 314.51 KiB/397.45 KiB
# datasets   ------------------------------ 302.88 KiB/480.03 KiB
# setuptools ------------------------------ 192.27 KiB/1.15 MiB
# aiohttp    ------------------------------ 940.66 KiB/1.65 MiB
# cryptography ------------------------------ 972.74 KiB/4.26 MiB
# hf-xet     ------------------------------ 1.03 MiB/4.60 MiB
# fonttools  ------------------------------ 1011.56 KiB/4.71 MiB
# xgrammar   ------------------------------ 992.00 KiB/5.56 MiB
# matplotlib ------------------------------ 569.71 KiB/8.21 MiB
# scikit-learn ------------------------------ 828.57 KiB/12.28 MiB
# pandas     ------------------------------ 396.33 KiB/12.45 MiB
# botocore   ------------------------------ 557.84 KiB/12.72 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 995.56 KiB/13.17 MiB
# plotly     ------------------------------ 351.08 KiB/15.51 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1008.00 KiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1006.51 KiB/23.50 MiB
# mostlyai-qa ------------------------------ 1018.65 KiB/29.25 MiB
# ⠧ Preparing packages... (26/60)
# boto3      ------------------------------ 136.08 KiB/136.08 KiB
# google-auth ------------------------------ 206.61 KiB/211.07 KiB
# opacus     ------------------------------ 95.45 KiB/248.40 KiB
# protobuf   ------------------------------ 313.54 KiB/313.54 KiB
# narwhals   ------------------------------ 222.88 KiB/349.64 KiB
# azure-storage-blob ------------------------------ 330.51 KiB/397.45 KiB
# datasets   ------------------------------ 302.88 KiB/480.03 KiB
# setuptools ------------------------------ 192.27 KiB/1.15 MiB
# aiohttp    ------------------------------ 940.66 KiB/1.65 MiB
# cryptography ------------------------------ 972.74 KiB/4.26 MiB
# hf-xet     ------------------------------ 1.03 MiB/4.60 MiB
# fonttools  ------------------------------ 1011.56 KiB/4.71 MiB
# xgrammar   ------------------------------ 992.00 KiB/5.56 MiB
# matplotlib ------------------------------ 569.71 KiB/8.21 MiB
# scikit-learn ------------------------------ 828.57 KiB/12.28 MiB
# pandas     ------------------------------ 396.44 KiB/12.45 MiB
# botocore   ------------------------------ 557.84 KiB/12.72 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 995.56 KiB/13.17 MiB
# plotly     ------------------------------ 351.08 KiB/15.51 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1008.00 KiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1006.51 KiB/23.50 MiB
# mostlyai-qa ------------------------------ 1018.65 KiB/29.25 MiB
# ⠧ Preparing packages... (26/60)
# google-auth ------------------------------ 206.61 KiB/211.07 KiB
# opacus     ------------------------------ 95.45 KiB/248.40 KiB
# protobuf   ------------------------------ 313.54 KiB/313.54 KiB
# narwhals   ------------------------------ 238.88 KiB/349.64 KiB
# azure-storage-blob ------------------------------ 330.51 KiB/397.45 KiB
# datasets   ------------------------------ 302.88 KiB/480.03 KiB
# setuptools ------------------------------ 204.69 KiB/1.15 MiB
# aiohttp    ------------------------------ 956.66 KiB/1.65 MiB
# cryptography ------------------------------ 1021.50 KiB/4.26 MiB
# hf-xet     ------------------------------ 1.09 MiB/4.60 MiB
# fonttools  ------------------------------ 1.04 MiB/4.71 MiB
# xgrammar   ------------------------------ 1.03 MiB/5.56 MiB
# matplotlib ------------------------------ 569.71 KiB/8.21 MiB
# scikit-learn ------------------------------ 844.57 KiB/12.28 MiB
# pandas     ------------------------------ 444.44 KiB/12.45 MiB
# botocore   ------------------------------ 557.84 KiB/12.72 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.03 MiB/13.17 MiB
# plotly     ------------------------------ 351.08 KiB/15.51 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.05 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.05 MiB/23.50 MiB
# mostlyai-qa ------------------------------ 1.05 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 1.03 MiB/53.70 MiB
# ⠧ Preparing packages... (26/60)
# google-auth ------------------------------ 211.07 KiB/211.07 KiB
# opacus     ------------------------------ 95.45 KiB/248.40 KiB
# protobuf   ------------------------------ 313.54 KiB/313.54 KiB
# narwhals   ------------------------------ 238.88 KiB/349.64 KiB
# azure-storage-blob ------------------------------ 330.51 KiB/397.45 KiB
# datasets   ------------------------------ 302.88 KiB/480.03 KiB
# setuptools ------------------------------ 204.69 KiB/1.15 MiB
# aiohttp    ------------------------------ 956.66 KiB/1.65 MiB
# cryptography ------------------------------ 1021.50 KiB/4.26 MiB
# hf-xet     ------------------------------ 1.09 MiB/4.60 MiB
# fonttools  ------------------------------ 1.04 MiB/4.71 MiB
# xgrammar   ------------------------------ 1.03 MiB/5.56 MiB
# matplotlib ------------------------------ 569.71 KiB/8.21 MiB
# scikit-learn ------------------------------ 846.78 KiB/12.28 MiB
# pandas     ------------------------------ 444.44 KiB/12.45 MiB
# botocore   ------------------------------ 557.84 KiB/12.72 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.03 MiB/13.17 MiB
# plotly     ------------------------------ 367.08 KiB/15.51 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.05 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.05 MiB/23.50 MiB
# mostlyai-qa ------------------------------ 1.05 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 1.03 MiB/53.70 MiB
# ⠧ Preparing packages... (26/60)
# opacus     ------------------------------ 95.45 KiB/248.40 KiB
# protobuf   ------------------------------ 313.54 KiB/313.54 KiB
# narwhals   ------------------------------ 238.88 KiB/349.64 KiB
# azure-storage-blob ------------------------------ 330.51 KiB/397.45 KiB
# datasets   ------------------------------ 302.88 KiB/480.03 KiB
# setuptools ------------------------------ 204.69 KiB/1.15 MiB
# aiohttp    ------------------------------ 956.66 KiB/1.65 MiB
# cryptography ------------------------------ 1021.50 KiB/4.26 MiB
# hf-xet     ------------------------------ 1.09 MiB/4.60 MiB
# fonttools  ------------------------------ 1.04 MiB/4.71 MiB
# xgrammar   ------------------------------ 1.03 MiB/5.56 MiB
# matplotlib ------------------------------ 569.71 KiB/8.21 MiB
# scikit-learn ------------------------------ 958.78 KiB/12.28 MiB
# pandas     ------------------------------ 444.44 KiB/12.45 MiB
# botocore   ------------------------------ 557.84 KiB/12.72 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.03 MiB/13.17 MiB
# plotly     ------------------------------ 367.08 KiB/15.51 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.05 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.05 MiB/23.50 MiB
# mostlyai-qa ------------------------------ 1.05 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 1.03 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.01 MiB/122.01 MiB
# ⠇ Preparing packages... (33/60)
# opacus     ------------------------------ 111.45 KiB/248.40 KiB
# protobuf   ------------------------------ 313.54 KiB/313.54 KiB
# narwhals   ------------------------------ 238.88 KiB/349.64 KiB
# azure-storage-blob ------------------------------ 348.29 KiB/397.45 KiB
# datasets   ------------------------------ 302.88 KiB/480.03 KiB
# setuptools ------------------------------ 204.69 KiB/1.15 MiB
# aiohttp    ------------------------------ 988.66 KiB/1.65 MiB
# cryptography ------------------------------ 1.04 MiB/4.26 MiB
# hf-xet     ------------------------------ 1.09 MiB/4.60 MiB
# fonttools  ------------------------------ 1.04 MiB/4.71 MiB
# xgrammar   ------------------------------ 1.03 MiB/5.56 MiB
# matplotlib ------------------------------ 569.71 KiB/8.21 MiB
# scikit-learn ------------------------------ 1.03 MiB/12.28 MiB
# pandas     ------------------------------ 469.69 KiB/12.45 MiB
# botocore   ------------------------------ 557.84 KiB/12.72 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.10 MiB/13.17 MiB
# plotly     ------------------------------ 383.08 KiB/15.51 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.09 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.05 MiB/23.50 MiB
# mostlyai-qa ------------------------------ 1.05 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 1.03 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.06 MiB/122.01 MiB
# ⠇ Preparing packages... (33/60)
# opacus     ------------------------------ 111.45 KiB/248.40 KiB
# protobuf   ------------------------------ 313.54 KiB/313.54 KiB
# narwhals   ------------------------------ 254.88 KiB/349.64 KiB
# azure-storage-blob ------------------------------ 364.29 KiB/397.45 KiB
# datasets   ------------------------------ 302.88 KiB/480.03 KiB
# setuptools ------------------------------ 220.69 KiB/1.15 MiB
# aiohttp    ------------------------------ 988.66 KiB/1.65 MiB
# cryptography ------------------------------ 1.11 MiB/4.26 MiB
# hf-xet     ------------------------------ 1.17 MiB/4.60 MiB
# fonttools  ------------------------------ 1.09 MiB/4.71 MiB
# xgrammar   ------------------------------ 1.11 MiB/5.56 MiB
# matplotlib ------------------------------ 617.81 KiB/8.21 MiB
# scikit-learn ------------------------------ 1.14 MiB/12.28 MiB
# pandas     ------------------------------ 476.58 KiB/12.45 MiB
# botocore   ------------------------------ 557.84 KiB/12.72 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.14 MiB/13.17 MiB
# plotly     ------------------------------ 415.08 KiB/15.51 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.16 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.12 MiB/23.50 MiB
# mostlyai-qa ------------------------------ 1.16 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 1.13 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.12 MiB/122.01 MiB
# ⠇ Preparing packages... (33/60)
# opacus     ------------------------------ 121.29 KiB/248.40 KiB
# protobuf   ------------------------------ 313.54 KiB/313.54 KiB
# narwhals   ------------------------------ 270.88 KiB/349.64 KiB
# azure-storage-blob ------------------------------ 380.29 KiB/397.45 KiB
# datasets   ------------------------------ 318.88 KiB/480.03 KiB
# setuptools ------------------------------ 236.59 KiB/1.15 MiB
# aiohttp    ------------------------------ 1020.66 KiB/1.65 MiB
# cryptography ------------------------------ 1.15 MiB/4.26 MiB
# hf-xet     ------------------------------ 1.20 MiB/4.60 MiB
# fonttools  ------------------------------ 1.12 MiB/4.71 MiB
# xgrammar   ------------------------------ 1.16 MiB/5.56 MiB
# matplotlib ------------------------------ 665.81 KiB/8.21 MiB
# scikit-learn ------------------------------ 1.16 MiB/12.28 MiB
# pandas     ------------------------------ 508.58 KiB/12.45 MiB
# botocore   ------------------------------ 589.84 KiB/12.72 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.18 MiB/13.17 MiB
# plotly     ------------------------------ 526.97 KiB/15.51 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.20 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.18 MiB/23.50 MiB
# mostlyai-qa ------------------------------ 1.17 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 1.18 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.15 MiB/122.01 MiB
# ⠇ Preparing packages... (33/60)
# opacus     ------------------------------ 121.29 KiB/248.40 KiB
# protobuf   ------------------------------ 313.54 KiB/313.54 KiB
# narwhals   ------------------------------ 270.88 KiB/349.64 KiB
# datasets   ------------------------------ 318.88 KiB/480.03 KiB
# setuptools ------------------------------ 252.59 KiB/1.15 MiB
# aiohttp    ------------------------------ 1.02 MiB/1.65 MiB
# cryptography ------------------------------ 1.20 MiB/4.26 MiB
# hf-xet     ------------------------------ 1.25 MiB/4.60 MiB
# fonttools  ------------------------------ 1.13 MiB/4.71 MiB
# xgrammar   ------------------------------ 1.20 MiB/5.56 MiB
# matplotlib ------------------------------ 980.59 KiB/8.21 MiB
# scikit-learn ------------------------------ 1.20 MiB/12.28 MiB
# pandas     ------------------------------ 524.44 KiB/12.45 MiB
# botocore   ------------------------------ 647.64 KiB/12.72 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.22 MiB/13.17 MiB
# plotly     ------------------------------ 655.08 KiB/15.51 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.23 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.23 MiB/23.50 MiB
# mostlyai-qa ------------------------------ 1.22 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 1.23 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.19 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.17 MiB/197.84 MiB
# ⠇ Preparing packages... (33/60)
# opacus     ------------------------------ 137.29 KiB/248.40 KiB
# protobuf   ------------------------------ 313.54 KiB/313.54 KiB
# narwhals   ------------------------------ 270.88 KiB/349.64 KiB
# datasets   ------------------------------ 318.88 KiB/480.03 KiB
# setuptools ------------------------------ 252.59 KiB/1.15 MiB
# aiohttp    ------------------------------ 1.02 MiB/1.65 MiB
# cryptography ------------------------------ 1.20 MiB/4.26 MiB
# hf-xet     ------------------------------ 1.25 MiB/4.60 MiB
# fonttools  ------------------------------ 1.13 MiB/4.71 MiB
# xgrammar   ------------------------------ 1.20 MiB/5.56 MiB
# matplotlib ------------------------------ 980.59 KiB/8.21 MiB
# scikit-learn ------------------------------ 1.20 MiB/12.28 MiB
# pandas     ------------------------------ 524.44 KiB/12.45 MiB
# botocore   ------------------------------ 647.64 KiB/12.72 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.22 MiB/13.17 MiB
# plotly     ------------------------------ 655.08 KiB/15.51 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.23 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.23 MiB/23.50 MiB
# mostlyai-qa ------------------------------ 1.22 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 1.23 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.19 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.17 MiB/197.84 MiB
# ⠋ Preparing packages... (35/60)
# opacus     ------------------------------ 153.29 KiB/248.40 KiB
# protobuf   ------------------------------ 313.54 KiB/313.54 KiB
# narwhals   ------------------------------ 270.88 KiB/349.64 KiB
# datasets   ------------------------------ 318.88 KiB/480.03 KiB
# setuptools ------------------------------ 268.59 KiB/1.15 MiB
# aiohttp    ------------------------------ 1.04 MiB/1.65 MiB
# cryptography ------------------------------ 1.25 MiB/4.26 MiB
# hf-xet     ------------------------------ 1.29 MiB/4.60 MiB
# fonttools  ------------------------------ 1.24 MiB/4.71 MiB
# xgrammar   ------------------------------ 1.23 MiB/5.56 MiB
# matplotlib ------------------------------ 1.11 MiB/8.21 MiB
# scikit-learn ------------------------------ 1.33 MiB/12.28 MiB
# pandas     ------------------------------ 524.44 KiB/12.45 MiB
# botocore   ------------------------------ 718.89 KiB/12.72 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.27 MiB/13.17 MiB
# plotly     ------------------------------ 719.08 KiB/15.51 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.28 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.27 MiB/23.50 MiB
# mostlyai-qa ------------------------------ 1.27 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 1.26 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.23 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.22 MiB/197.84 MiB
# ⠋ Preparing packages... (35/60)
# opacus     ------------------------------ 169.29 KiB/248.40 KiB
# protobuf   ------------------------------ 313.54 KiB/313.54 KiB
# narwhals   ------------------------------ 286.88 KiB/349.64 KiB
# datasets   ------------------------------ 334.88 KiB/480.03 KiB
# setuptools ------------------------------ 284.69 KiB/1.15 MiB
# aiohttp    ------------------------------ 1.07 MiB/1.65 MiB
# cryptography ------------------------------ 1.31 MiB/4.26 MiB
# hf-xet     ------------------------------ 1.36 MiB/4.60 MiB
# fonttools  ------------------------------ 1.30 MiB/4.71 MiB
# xgrammar   ------------------------------ 1.28 MiB/5.56 MiB
# matplotlib ------------------------------ 1.13 MiB/8.21 MiB
# scikit-learn ------------------------------ 1.33 MiB/12.28 MiB
# pandas     ------------------------------ 524.44 KiB/12.45 MiB
# botocore   ------------------------------ 718.89 KiB/12.72 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.31 MiB/13.17 MiB
# plotly     ------------------------------ 767.08 KiB/15.51 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.34 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.34 MiB/23.50 MiB
# mostlyai-qa ------------------------------ 1.34 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 1.30 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.29 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.28 MiB/197.84 MiB
# ⠋ Preparing packages... (35/60)
# opacus     ------------------------------ 169.29 KiB/248.40 KiB
# protobuf   ------------------------------ 313.54 KiB/313.54 KiB
# narwhals   ------------------------------ 302.88 KiB/349.64 KiB
# datasets   ------------------------------ 334.88 KiB/480.03 KiB
# setuptools ------------------------------ 311.57 KiB/1.15 MiB
# aiohttp    ------------------------------ 1.37 MiB/1.65 MiB
# cryptography ------------------------------ 1.37 MiB/4.26 MiB
# hf-xet     ------------------------------ 1.42 MiB/4.60 MiB
# fonttools  ------------------------------ 1.33 MiB/4.71 MiB
# xgrammar   ------------------------------ 1.33 MiB/5.56 MiB
# matplotlib ------------------------------ 1.13 MiB/8.21 MiB
# scikit-learn ------------------------------ 1.37 MiB/12.28 MiB
# pandas     ------------------------------ 540.44 KiB/12.45 MiB
# botocore   ------------------------------ 765.84 KiB/12.72 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.38 MiB/13.17 MiB
# plotly     ------------------------------ 783.08 KiB/15.51 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.40 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.38 MiB/23.50 MiB
# mostlyai-qa ------------------------------ 1.39 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 1.36 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.36 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.35 MiB/197.84 MiB
# ⠋ Preparing packages... (35/60)
# opacus     ------------------------------ 189.13 KiB/248.40 KiB
# protobuf   ------------------------------ 313.54 KiB/313.54 KiB
# narwhals   ------------------------------ 318.88 KiB/349.64 KiB
# datasets   ------------------------------ 350.88 KiB/480.03 KiB
# setuptools ------------------------------ 327.57 KiB/1.15 MiB
# aiohttp    ------------------------------ 1.48 MiB/1.65 MiB
# cryptography ------------------------------ 1.43 MiB/4.26 MiB
# hf-xet     ------------------------------ 1.48 MiB/4.60 MiB
# fonttools  ------------------------------ 1.42 MiB/4.71 MiB
# xgrammar   ------------------------------ 1.42 MiB/5.56 MiB
# matplotlib ------------------------------ 1.21 MiB/8.21 MiB
# scikit-learn ------------------------------ 1.41 MiB/12.28 MiB
# pandas     ------------------------------ 540.44 KiB/12.45 MiB
# botocore   ------------------------------ 797.84 KiB/12.72 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.44 MiB/13.17 MiB
# plotly     ------------------------------ 926.86 KiB/15.51 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.48 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.45 MiB/23.50 MiB
# mostlyai-qa ------------------------------ 1.44 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 1.42 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.39 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.42 MiB/197.84 MiB
# ⠙ Preparing packages... (35/60)
# opacus     ------------------------------ 189.13 KiB/248.40 KiB
# protobuf   ------------------------------ 313.54 KiB/313.54 KiB
# narwhals   ------------------------------ 334.88 KiB/349.64 KiB
# datasets   ------------------------------ 366.88 KiB/480.03 KiB
# setuptools ------------------------------ 348.69 KiB/1.15 MiB
# aiohttp    ------------------------------ 1.53 MiB/1.65 MiB
# cryptography ------------------------------ 1.50 MiB/4.26 MiB
# hf-xet     ------------------------------ 1.54 MiB/4.60 MiB
# fonttools  ------------------------------ 1.46 MiB/4.71 MiB
# xgrammar   ------------------------------ 1.47 MiB/5.56 MiB
# matplotlib ------------------------------ 1.47 MiB/8.21 MiB
# scikit-learn ------------------------------ 1.51 MiB/12.28 MiB
# pandas     ------------------------------ 572.44 KiB/12.45 MiB
# botocore   ------------------------------ 837.07 KiB/12.72 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.45 MiB/13.17 MiB
# plotly     ------------------------------ 982.03 KiB/15.51 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.53 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.51 MiB/23.50 MiB
# mostlyai-qa ------------------------------ 1.50 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 1.43 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.45 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.45 MiB/197.84 MiB
# ⠙ Preparing packages... (35/60)
# opacus     ------------------------------ 189.13 KiB/248.40 KiB
# protobuf   ------------------------------ 313.54 KiB/313.54 KiB
# narwhals   ------------------------------ 334.88 KiB/349.64 KiB
# datasets   ------------------------------ 382.88 KiB/480.03 KiB
# setuptools ------------------------------ 348.69 KiB/1.15 MiB
# aiohttp    ------------------------------ 1.57 MiB/1.65 MiB
# cryptography ------------------------------ 1.61 MiB/4.26 MiB
# hf-xet     ------------------------------ 1.61 MiB/4.60 MiB
# fonttools  ------------------------------ 1.55 MiB/4.71 MiB
# xgrammar   ------------------------------ 1.53 MiB/5.56 MiB
# matplotlib ------------------------------ 1.52 MiB/8.21 MiB
# scikit-learn ------------------------------ 1.53 MiB/12.28 MiB
# pandas     ------------------------------ 588.44 KiB/12.45 MiB
# botocore   ------------------------------ 877.84 KiB/12.72 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.56 MiB/13.17 MiB
# plotly     ------------------------------ 982.03 KiB/15.51 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.58 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.60 MiB/23.50 MiB
# mostlyai-qa ------------------------------ 1.55 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 1.53 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.48 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.52 MiB/197.84 MiB
# ⠙ Preparing packages... (35/60)
# opacus     ------------------------------ 205.13 KiB/248.40 KiB
# protobuf   ------------------------------ 313.54 KiB/313.54 KiB
# narwhals   ------------------------------ 349.64 KiB/349.64 KiB
# datasets   ------------------------------ 392.56 KiB/480.03 KiB
# setuptools ------------------------------ 364.69 KiB/1.15 MiB
# aiohttp    ------------------------------ 1.62 MiB/1.65 MiB
# cryptography ------------------------------ 1.65 MiB/4.26 MiB
# hf-xet     ------------------------------ 1.68 MiB/4.60 MiB
# fonttools  ------------------------------ 1.64 MiB/4.71 MiB
# xgrammar   ------------------------------ 1.61 MiB/5.56 MiB
# matplotlib ------------------------------ 1.58 MiB/8.21 MiB
# scikit-learn ------------------------------ 1.66 MiB/12.28 MiB
# pandas     ------------------------------ 604.44 KiB/12.45 MiB
# botocore   ------------------------------ 893.84 KiB/12.72 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.63 MiB/13.17 MiB
# plotly     ------------------------------ 982.03 KiB/15.51 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.66 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.65 MiB/23.50 MiB
# mostlyai-qa ------------------------------ 1.62 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 1.61 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.58 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.61 MiB/197.84 MiB
# ⠙ Preparing packages... (35/60)
# opacus     ------------------------------ 205.13 KiB/248.40 KiB
# protobuf   ------------------------------ 313.54 KiB/313.54 KiB
# datasets   ------------------------------ 392.56 KiB/480.03 KiB
# setuptools ------------------------------ 364.69 KiB/1.15 MiB
# aiohttp    ------------------------------ 1.62 MiB/1.65 MiB
# cryptography ------------------------------ 1.65 MiB/4.26 MiB
# hf-xet     ------------------------------ 1.68 MiB/4.60 MiB
# fonttools  ------------------------------ 1.64 MiB/4.71 MiB
# xgrammar   ------------------------------ 1.61 MiB/5.56 MiB
# matplotlib ------------------------------ 1.58 MiB/8.21 MiB
# scikit-learn ------------------------------ 1.66 MiB/12.28 MiB
# pandas     ------------------------------ 604.44 KiB/12.45 MiB
# botocore   ------------------------------ 893.84 KiB/12.72 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.63 MiB/13.17 MiB
# plotly     ------------------------------ 982.03 KiB/15.51 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.66 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.65 MiB/23.50 MiB
# mostlyai-qa ------------------------------ 1.62 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 1.61 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.58 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.61 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 1.63 MiB/201.66 MiB
# ⠙ Preparing packages... (35/60)
# opacus     ------------------------------ 205.13 KiB/248.40 KiB
# datasets   ------------------------------ 392.56 KiB/480.03 KiB
# setuptools ------------------------------ 364.69 KiB/1.15 MiB
# aiohttp    ------------------------------ 1.62 MiB/1.65 MiB
# cryptography ------------------------------ 1.65 MiB/4.26 MiB
# hf-xet     ------------------------------ 1.68 MiB/4.60 MiB
# fonttools  ------------------------------ 1.64 MiB/4.71 MiB
# xgrammar   ------------------------------ 1.61 MiB/5.56 MiB
# matplotlib ------------------------------ 1.58 MiB/8.21 MiB
# scikit-learn ------------------------------ 1.66 MiB/12.28 MiB
# pandas     ------------------------------ 604.44 KiB/12.45 MiB
# botocore   ------------------------------ 893.84 KiB/12.72 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.63 MiB/13.17 MiB
# plotly     ------------------------------ 982.03 KiB/15.51 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.66 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.65 MiB/23.50 MiB
# mostlyai-qa ------------------------------ 1.62 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 1.61 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.58 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.61 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 1.63 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 1.62 MiB/346.60 MiB
# ⠙ Preparing packages... (35/60)
# opacus     ------------------------------ 221.13 KiB/248.40 KiB
# datasets   ------------------------------ 456.56 KiB/480.03 KiB
# setuptools ------------------------------ 364.69 KiB/1.15 MiB
# aiohttp    ------------------------------ 1.64 MiB/1.65 MiB
# cryptography ------------------------------ 1.76 MiB/4.26 MiB
# hf-xet     ------------------------------ 1.76 MiB/4.60 MiB
# fonttools  ------------------------------ 1.76 MiB/4.71 MiB
# xgrammar   ------------------------------ 1.70 MiB/5.56 MiB
# matplotlib ------------------------------ 1.69 MiB/8.21 MiB
# scikit-learn ------------------------------ 1.78 MiB/12.28 MiB
# pandas     ------------------------------ 620.33 KiB/12.45 MiB
# botocore   ------------------------------ 925.84 KiB/12.72 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.74 MiB/13.17 MiB
# plotly     ------------------------------ 992.17 KiB/15.51 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.75 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.77 MiB/23.50 MiB
# mostlyai-qa ------------------------------ 1.72 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 1.72 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.67 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.74 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 1.72 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 1.74 MiB/346.60 MiB
# ⠹ Preparing packages... (37/60)
# opacus     ------------------------------ 221.13 KiB/248.40 KiB
# datasets   ------------------------------ 466.24 KiB/480.03 KiB
# setuptools ------------------------------ 380.69 KiB/1.15 MiB
# aiohttp    ------------------------------ 1.65 MiB/1.65 MiB
# cryptography ------------------------------ 1.86 MiB/4.26 MiB
# hf-xet     ------------------------------ 1.81 MiB/4.60 MiB
# fonttools  ------------------------------ 1.81 MiB/4.71 MiB
# xgrammar   ------------------------------ 1.75 MiB/5.56 MiB
# matplotlib ------------------------------ 1.72 MiB/8.21 MiB
# scikit-learn ------------------------------ 1.80 MiB/12.28 MiB
# pandas     ------------------------------ 620.33 KiB/12.45 MiB
# botocore   ------------------------------ 925.84 KiB/12.72 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.85 MiB/13.17 MiB
# plotly     ------------------------------ 1007.08 KiB/15.51 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.80 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.82 MiB/23.50 MiB
# mostlyai-qa ------------------------------ 1.81 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 1.82 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.72 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.75 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 1.85 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 1.77 MiB/346.60 MiB
# ⠹ Preparing packages... (37/60)
# opacus     ------------------------------ 221.13 KiB/248.40 KiB
# datasets   ------------------------------ 466.24 KiB/480.03 KiB
# setuptools ------------------------------ 380.69 KiB/1.15 MiB
# cryptography ------------------------------ 1.86 MiB/4.26 MiB
# hf-xet     ------------------------------ 1.89 MiB/4.60 MiB
# fonttools  ------------------------------ 1.86 MiB/4.71 MiB
# xgrammar   ------------------------------ 1.81 MiB/5.56 MiB
# matplotlib ------------------------------ 1.78 MiB/8.21 MiB
# scikit-learn ------------------------------ 1.80 MiB/12.28 MiB
# pandas     ------------------------------ 620.33 KiB/12.45 MiB
# botocore   ------------------------------ 925.84 KiB/12.72 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.85 MiB/13.17 MiB
# plotly     ------------------------------ 1007.08 KiB/15.51 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.86 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.88 MiB/23.50 MiB
# mostlyai-qa ------------------------------ 1.81 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 1.82 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.79 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.81 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 1.85 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 1.82 MiB/346.60 MiB
# ⠹ Preparing packages... (37/60)
# datasets   ------------------------------ 466.24 KiB/480.03 KiB
# setuptools ------------------------------ 396.69 KiB/1.15 MiB
# cryptography ------------------------------ 1.86 MiB/4.26 MiB
# hf-xet     ------------------------------ 1.89 MiB/4.60 MiB
# fonttools  ------------------------------ 1.86 MiB/4.71 MiB
# xgrammar   ------------------------------ 1.81 MiB/5.56 MiB
# matplotlib ------------------------------ 1.78 MiB/8.21 MiB
# scikit-learn ------------------------------ 1.86 MiB/12.28 MiB
# pandas     ------------------------------ 652.33 KiB/12.45 MiB
# botocore   ------------------------------ 957.84 KiB/12.72 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.85 MiB/13.17 MiB
# plotly     ------------------------------ 1007.08 KiB/15.51 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.86 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.88 MiB/23.50 MiB
# mostlyai-qa ------------------------------ 1.81 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 1.82 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.79 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.81 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 1.85 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 1.82 MiB/346.60 MiB
# ⠹ Preparing packages... (37/60)
# setuptools ------------------------------ 396.69 KiB/1.15 MiB
# cryptography ------------------------------ 1.86 MiB/4.26 MiB
# hf-xet     ------------------------------ 1.89 MiB/4.60 MiB
# fonttools  ------------------------------ 1.86 MiB/4.71 MiB
# xgrammar   ------------------------------ 1.81 MiB/5.56 MiB
# matplotlib ------------------------------ 1.78 MiB/8.21 MiB
# scikit-learn ------------------------------ 1.88 MiB/12.28 MiB
# pandas     ------------------------------ 652.33 KiB/12.45 MiB
# botocore   ------------------------------ 973.84 KiB/12.72 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.85 MiB/13.17 MiB
# plotly     ------------------------------ 1007.08 KiB/15.51 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.86 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.88 MiB/23.50 MiB
# mostlyai-qa ------------------------------ 1.82 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 1.82 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.79 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.81 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 1.85 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 1.82 MiB/346.60 MiB
# ⠹ Preparing packages... (37/60)
# setuptools ------------------------------ 412.59 KiB/1.15 MiB
# cryptography ------------------------------ 1.86 MiB/4.26 MiB
# hf-xet     ------------------------------ 1.89 MiB/4.60 MiB
# fonttools  ------------------------------ 1.92 MiB/4.71 MiB
# xgrammar   ------------------------------ 1.86 MiB/5.56 MiB
# matplotlib ------------------------------ 1.81 MiB/8.21 MiB
# scikit-learn ------------------------------ 1.88 MiB/12.28 MiB
# pandas     ------------------------------ 652.33 KiB/12.45 MiB
# botocore   ------------------------------ 973.84 KiB/12.72 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.85 MiB/13.17 MiB
# plotly     ------------------------------ 1007.08 KiB/15.51 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.89 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.94 MiB/23.50 MiB
# mostlyai-qa ------------------------------ 1.82 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 1.82 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.79 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.86 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 1.85 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 1.87 MiB/346.60 MiB
# ⠹ Preparing packages... (37/60)
# setuptools ------------------------------ 476.59 KiB/1.15 MiB
# cryptography ------------------------------ 1.96 MiB/4.26 MiB
# hf-xet     ------------------------------ 1.97 MiB/4.60 MiB
# fonttools  ------------------------------ 1.98 MiB/4.71 MiB
# xgrammar   ------------------------------ 1.92 MiB/5.56 MiB
# matplotlib ------------------------------ 1.86 MiB/8.21 MiB
# scikit-learn ------------------------------ 1.94 MiB/12.28 MiB
# pandas     ------------------------------ 668.44 KiB/12.45 MiB
# botocore   ------------------------------ 1.03 MiB/12.72 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 1.97 MiB/13.17 MiB
# plotly     ------------------------------ 1023.08 KiB/15.51 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 1.98 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 1.99 MiB/23.50 MiB
# mostlyai-qa ------------------------------ 1.92 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 1.93 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 1.91 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 1.92 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 1.97 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 1.91 MiB/346.60 MiB
# ⠹ Preparing packages... (37/60)
# setuptools ------------------------------ 492.59 KiB/1.15 MiB
# cryptography ------------------------------ 2.07 MiB/4.26 MiB
# hf-xet     ------------------------------ 2.06 MiB/4.60 MiB
# fonttools  ------------------------------ 2.11 MiB/4.71 MiB
# xgrammar   ------------------------------ 2.03 MiB/5.56 MiB
# matplotlib ------------------------------ 1.96 MiB/8.21 MiB
# scikit-learn ------------------------------ 2.09 MiB/12.28 MiB
# pandas     ------------------------------ 732.44 KiB/12.45 MiB
# botocore   ------------------------------ 1.09 MiB/12.72 MiB
# nvidia-cuda-cupti-cu12 ------------------------------ 2.08 MiB/13.17 MiB
# plotly     ------------------------------ 1.01 MiB/15.51 MiB
# nvidia-nvjitlink-cu12 ------------------------------ 2.09 MiB/20.09 MiB
# nvidia-cuda-nvrtc-cu12 ------------------------------ 2.10 MiB/23.50 MiB
# mostlyai-qa ------------------------------ 2.02 MiB/29.25 MiB
# nvidia-curand-cu12 ------------------------------ 2.04 MiB/53.70 MiB
# nvidia-cusolver-cu12 ------------------------------ 2.00 MiB/122.01 MiB
# nvidia-cusparse-cu12 ------------------------------ 2.05 MiB/197.84 MiB
# nvidia-cufft-cu12 ------------------------------ 2.08 MiB/201.66 MiB
# nvidia-cublas-cu12 ------------------------------ 2.02 MiB/346.60 MiB
# ⠸ Preparing packages... (40/60)
# setuptools ------------------------------ 530.61 KiB/1.15 MiB
# cryptography ------------------------------ 2.15 MiB/4.26 MiB
# ...
# nvidia-cublas-cu12 ------------------------------ 299.02 MiB/346.60 MiB
# ⠹ Preparing packages... (57/60)
# plotly     ------------------------------ 8.85 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 299.02 MiB/346.60 MiB
# ⠸ Preparing packages... (57/60)
# plotly     ------------------------------ 8.85 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 299.02 MiB/346.60 MiB
# ⠼ Preparing packages... (57/60)
# plotly     ------------------------------ 8.85 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 299.02 MiB/346.60 MiB
# ⠴ Preparing packages... (57/60)
# plotly     ------------------------------ 8.85 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 299.02 MiB/346.60 MiB
# ⠦ Preparing packages... (57/60)
# plotly     ------------------------------ 8.85 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 299.02 MiB/346.60 MiB
# ⠧ Preparing packages... (57/60)
# plotly     ------------------------------ 8.85 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 299.02 MiB/346.60 MiB
# ⠧ Preparing packages... (57/60)
# plotly     ------------------------------ 8.85 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 299.03 MiB/346.60 MiB
# ⠧ Preparing packages... (57/60)
# plotly     ------------------------------ 8.85 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 299.05 MiB/346.60 MiB
# ⠧ Preparing packages... (57/60)
# plotly     ------------------------------ 8.85 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 299.06 MiB/346.60 MiB
# ⠧ Preparing packages... (57/60)
# plotly     ------------------------------ 8.85 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 299.07 MiB/346.60 MiB
# ⠧ Preparing packages... (57/60)
# plotly     ------------------------------ 8.85 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 299.09 MiB/346.60 MiB
# ⠧ Preparing packages... (57/60)
# plotly     ------------------------------ 8.85 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 299.11 MiB/346.60 MiB
# ⠧ Preparing packages... (57/60)
# plotly     ------------------------------ 8.85 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 299.12 MiB/346.60 MiB
# ⠧ Preparing packages... (57/60)
# plotly     ------------------------------ 8.85 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 299.14 MiB/346.60 MiB
# ⠧ Preparing packages... (57/60)
# plotly     ------------------------------ 8.85 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 299.15 MiB/346.60 MiB
# ⠧ Preparing packages... (57/60)
# plotly     ------------------------------ 8.85 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 299.17 MiB/346.60 MiB
# ⠧ Preparing packages... (57/60)
# plotly     ------------------------------ 8.85 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 299.18 MiB/346.60 MiB
# ⠧ Preparing packages... (57/60)
# plotly     ------------------------------ 8.85 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 299.20 MiB/346.60 MiB
# ⠧ Preparing packages... (57/60)
# plotly     ------------------------------ 8.85 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 299.22 MiB/346.60 MiB
# ⠧ Preparing packages... (57/60)
# plotly     ------------------------------ 8.85 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 299.23 MiB/346.60 MiB
# ⠧ Preparing packages... (57/60)
# plotly     ------------------------------ 8.85 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 299.25 MiB/346.60 MiB
# ⠧ Preparing packages... (57/60)
# plotly     ------------------------------ 8.85 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 299.25 MiB/346.60 MiB
# ⠧ Preparing packages... (57/60)
# plotly     ------------------------------ 8.85 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 299.28 MiB/346.60 MiB
# ⠧ Preparing packages... (57/60)
# plotly     ------------------------------ 8.85 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 299.36 MiB/346.60 MiB
# ⠧ Preparing packages... (57/60)
# plotly     ------------------------------ 8.85 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 299.40 MiB/346.60 MiB
# ⠧ Preparing packages... (57/60)
# plotly     ------------------------------ 8.85 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 299.48 MiB/346.60 MiB
# ⠧ Preparing packages... (57/60)
# plotly     ------------------------------ 8.85 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 299.57 MiB/346.60 MiB
# ⠇ Preparing packages... (57/60)
# plotly     ------------------------------ 8.85 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 300.94 MiB/346.60 MiB
# ⠇ Preparing packages... (57/60)
# plotly     ------------------------------ 8.87 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 302.58 MiB/346.60 MiB
# ⠇ Preparing packages... (57/60)
# plotly     ------------------------------ 8.89 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 303.80 MiB/346.60 MiB
# ⠇ Preparing packages... (57/60)
# plotly     ------------------------------ 8.90 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 304.62 MiB/346.60 MiB
# ⠋ Preparing packages... (57/60)
# plotly     ------------------------------ 8.90 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 306.75 MiB/346.60 MiB
# ⠋ Preparing packages... (57/60)
# plotly     ------------------------------ 8.90 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 308.98 MiB/346.60 MiB
# ⠋ Preparing packages... (57/60)
# plotly     ------------------------------ 8.90 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 310.45 MiB/346.60 MiB
# ⠋ Preparing packages... (57/60)
# plotly     ------------------------------ 8.90 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 313.11 MiB/346.60 MiB
# ⠙ Preparing packages... (57/60)
# plotly     ------------------------------ 8.90 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 316.00 MiB/346.60 MiB
# ⠙ Preparing packages... (57/60)
# plotly     ------------------------------ 8.92 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 319.19 MiB/346.60 MiB
# ⠙ Preparing packages... (57/60)
# plotly     ------------------------------ 8.92 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 321.97 MiB/346.60 MiB
# ⠙ Preparing packages... (57/60)
# plotly     ------------------------------ 8.92 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 324.39 MiB/346.60 MiB
# ⠹ Preparing packages... (57/60)
# plotly     ------------------------------ 8.92 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 327.61 MiB/346.60 MiB
# ⠹ Preparing packages... (57/60)
# plotly     ------------------------------ 8.92 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 330.59 MiB/346.60 MiB
# ⠹ Preparing packages... (57/60)
# plotly     ------------------------------ 8.92 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 334.10 MiB/346.60 MiB
# ⠹ Preparing packages... (57/60)
# plotly     ------------------------------ 8.93 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 335.78 MiB/346.60 MiB
# ⠸ Preparing packages... (57/60)
# plotly     ------------------------------ 8.97 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 338.59 MiB/346.60 MiB
# ⠸ Preparing packages... (57/60)
# plotly     ------------------------------ 9.04 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 338.59 MiB/346.60 MiB
# ⠸ Preparing packages... (57/60)
# plotly     ------------------------------ 9.12 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 338.59 MiB/346.60 MiB
# ⠸ Preparing packages... (57/60)
# plotly     ------------------------------ 9.18 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 341.88 MiB/346.60 MiB
# ⠼ Preparing packages... (57/60)
# plotly     ------------------------------ 9.30 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 343.56 MiB/346.60 MiB
# ⠼ Preparing packages... (57/60)
# plotly     ------------------------------ 9.46 MiB/15.51 MiB
# nvidia-cublas-cu12 ------------------------------ 345.89 MiB/346.60 MiB
# ⠼ Preparing packages... (57/60)
# plotly     ------------------------------ 9.52 MiB/15.51 MiB
# ⠼ Preparing packages... (57/60)
# plotly     ------------------------------ 9.59 MiB/15.51 MiB
# ⠼ Preparing packages... (57/60)
# plotly     ------------------------------ 9.66 MiB/15.51 MiB
# ⠴ Preparing packages... (58/60)
# plotly     ------------------------------ 9.66 MiB/15.51 MiB
# ⠴ Preparing packages... (58/60)
# plotly     ------------------------------ 9.68 MiB/15.51 MiB
# ⠴ Preparing packages... (58/60)
# plotly     ------------------------------ 9.69 MiB/15.51 MiB
# ⠴ Preparing packages... (58/60)
# plotly     ------------------------------ 9.74 MiB/15.51 MiB
# ⠦ Preparing packages... (58/60)
# plotly     ------------------------------ 9.82 MiB/15.51 MiB
# ⠦ Preparing packages... (58/60)
# plotly     ------------------------------ 9.83 MiB/15.51 MiB
# ⠦ Preparing packages... (58/60)
# plotly     ------------------------------ 9.83 MiB/15.51 MiB
# ⠦ Preparing packages... (58/60)
# plotly     ------------------------------ 9.88 MiB/15.51 MiB
# ⠧ Preparing packages... (58/60)
# plotly     ------------------------------ 10.07 MiB/15.51 MiB
# ⠧ Preparing packages... (58/60)
# plotly     ------------------------------ 10.25 MiB/15.51 MiB
# ⠧ Preparing packages... (58/60)
# plotly     ------------------------------ 10.48 MiB/15.51 MiB
# ⠧ Preparing packages... (58/60)
# plotly     ------------------------------ 10.72 MiB/15.51 MiB
# ⠇ Preparing packages... (58/60)
# plotly     ------------------------------ 10.95 MiB/15.51 MiB
# ⠇ Preparing packages... (58/60)
# plotly     ------------------------------ 11.18 MiB/15.51 MiB
# ⠇ Preparing packages... (58/60)
# plotly     ------------------------------ 11.38 MiB/15.51 MiB
# ⠇ Preparing packages... (58/60)
# plotly     ------------------------------ 11.61 MiB/15.51 MiB
# ⠋ Preparing packages... (58/60)
# plotly     ------------------------------ 11.81 MiB/15.51 MiB
# ⠋ Preparing packages... (58/60)
# plotly     ------------------------------ 12.03 MiB/15.51 MiB
# ⠋ Preparing packages... (58/60)
# plotly     ------------------------------ 12.24 MiB/15.51 MiB
# ⠋ Preparing packages... (58/60)
# plotly     ------------------------------ 14.17 MiB/15.51 MiB
# ⠙ Preparing packages... (58/60)
# plotly     ------------------------------ 14.33 MiB/15.51 MiB
# ⠙ Preparing packages... (58/60)
# ⠙ Preparing packages... (58/60)
# ⠙ Preparing packages... (58/60)
# ⠙ Preparing packages... (58/60)
# ⠹ Preparing packages... (59/60)
# ⠹ Preparing packages... (59/60)
# ⠹ Preparing packages... (59/60)
# ⠹ Preparing packages... (59/60)
# ⠸ Preparing packages... (59/60)
# ⠸ Preparing packages... (59/60)
# ⠸ Preparing packages... (59/60)
# ⠸ Preparing packages... (59/60)
# ⠼ Preparing packages... (59/60)
# ⠼ Preparing packages... (59/60)
# ⠼ Preparing packages... (59/60)
# ⠼ Preparing packages... (59/60)
# ⠴ Preparing packages... (59/60)
# ⠴ Preparing packages... (59/60)
# ⠴ Preparing packages... (59/60)
# ⠴ Preparing packages... (59/60)
# ⠦ Preparing packages... (59/60)
# ⠦ Preparing packages... (59/60)
# ⠦ Preparing packages... (59/60)
# ⠦ Preparing packages... (59/60)
# ⠧ Preparing packages... (59/60)
# ⠧ Preparing packages... (59/60)
# ⠧ Preparing packages... (59/60)
# ⠧ Preparing packages... (59/60)
# ⠇ Preparing packages... (59/60)
# ⠇ Preparing packages... (59/60)
# ⠇ Preparing packages... (59/60)
# ⠇ Preparing packages... (59/60)
# ⠋ Preparing packages... (59/60)
# ⠋ Preparing packages... (59/60)
# ⠋ Preparing packages... (59/60)
# ⠋ Preparing packages... (59/60)
# ⠙ Preparing packages... (59/60)
# ⠙ Preparing packages... (59/60)
# ⠙ Preparing packages... (59/60)
# ⠙ Preparing packages... (59/60)
# ⠹ Preparing packages... (59/60)
# ⠹ Preparing packages... (59/60)
# ⠹ Preparing packages... (59/60)
# ⠹ Preparing packages... (59/60)
# ⠸ Preparing packages... (59/60)
# ⠸ Preparing packages... (59/60)
# ⠸ Preparing packages... (59/60)
# ⠸ Preparing packages... (59/60)
# ⠼ Preparing packages... (59/60)
# ⠼ Preparing packages... (59/60)
# ⠼ Preparing packages... (59/60)
# ⠼ Preparing packages... (59/60)
# ⠴ Preparing packages... (59/60)
# ⠴ Preparing packages... (59/60)
# ⠴ Preparing packages... (59/60)
# ⠴ Preparing packages... (59/60)
# ⠦ Preparing packages... (59/60)
# ⠦ Preparing packages... (59/60)
# ⠦ Preparing packages... (59/60)
# ⠦ Preparing packages... (59/60)
# ⠧ Preparing packages... (59/60)
# ⠧ Preparing packages... (59/60)
# ⠧ Preparing packages... (59/60)
# ⠧ Preparing packages... (59/60)
# ⠇ Preparing packages... (59/60)
# ⠇ Preparing packages... (59/60)
# ⠇ Preparing packages... (59/60)
# ⠇ Preparing packages... (59/60)
# ⠋ Preparing packages... (59/60)
# ⠋ Preparing packages... (59/60)
# ⠋ Preparing packages... (59/60)
# ⠋ Preparing packages... (59/60)
# ⠙ Preparing packages... (59/60)
# ⠙ Preparing packages... (59/60)
# ⠙ Preparing packages... (59/60)
# ⠙ Preparing packages... (59/60)
# ⠹ Preparing packages... (59/60)
# ⠹ Preparing packages... (59/60)
# ⠹ Preparing packages... (59/60)
# ⠹ Preparing packages... (59/60)
# ⠸ Preparing packages... (59/60)
# ⠸ Preparing packages... (59/60)
# ⠸ Preparing packages... (59/60)
# ⠸ Preparing packages... (59/60)
# ⠼ Preparing packages... (59/60)
# ⠼ Preparing packages... (59/60)
# ⠼ Preparing packages... (59/60)
# ⠼ Preparing packages... (59/60)
# ⠴ Preparing packages... (59/60)
# ⠴ Preparing packages... (59/60)
# ⠴ Preparing packages... (59/60)
# ⠴ Preparing packages... (59/60)
# ⠦ Preparing packages... (59/60)
# ⠦ Preparing packages... (59/60)
# ⠦ Preparing packages... (59/60)
# ⠦ Preparing packages... (59/60)
# ⠧ Preparing packages... (59/60)
# ⠧ Preparing packages... (59/60)
# ⠧ Preparing packages... (59/60)
# ⠧ Preparing packages... (59/60)
# ⠇ Preparing packages... (59/60)
# ⠇ Preparing packages... (59/60)
# ⠇ Preparing packages... (59/60)
# Prepared 60 packages in 34.02s
# Uninstalled 30 packages in 1.16s
# Installed 60 packages in 523ms
#  + adlfs==2024.12.0
#  + aiobotocore==2.22.0
#  - aiohttp==3.11.15
#  + aiohttp==3.12.9
#  + aioitertools==0.12.0
#  + azure-common==1.1.28
#  + azure-core==1.34.0
#  + azure-datalake-store==0.0.53
#  + azure-identity==1.23.0
#  + azure-storage-blob==12.25.1
#  + azure-storage-file-datalake==12.20.0
#  + bcrypt==4.3.0
#  + boto3==1.37.3
#  + botocore==1.37.3
#  - cryptography==43.0.3
#  + cryptography==45.0.3
#  - datasets==2.14.4
#  + datasets==3.6.0
#  - dill==0.3.7
#  + dill==0.3.8
#  - fonttools==4.58.1
#  + fonttools==4.58.2
#  - frozenlist==1.6.0
#  + frozenlist==1.6.2
#  - fsspec==2025.3.2
#  + fsspec==2025.3.0
#  - gcsfs==2025.3.2
#  + gcsfs==2025.3.0
#  - google-auth==2.38.0
#  + google-auth==2.40.3
#  - google-cloud-storage==2.19.0
#  + google-cloud-storage==3.1.0
#  - hf-xet==1.1.2
#  + hf-xet==1.1.3
#  + isodate==0.7.2
#  + jmespath==1.0.1
#  + json-repair==0.46.2
#  - matplotlib==3.10.0
#  + matplotlib==3.10.3
#  + model2vec==0.6.0
#  + mostlyai-engine==1.4.3
#  + mostlyai-qa==1.9.7
#  + msal==1.32.3
#  + msal-extensions==1.3.1
#  - multiprocess==0.70.15
#  + multiprocess==0.70.16
#  - narwhals==1.41.0
#  + narwhals==1.41.1
#  + ninja==1.11.1.4
#  - nvidia-cublas-cu12==12.5.3.2
#  + nvidia-cublas-cu12==12.4.5.8
#  - nvidia-cuda-cupti-cu12==12.5.82
#  + nvidia-cuda-cupti-cu12==12.4.127
#  - nvidia-cuda-nvrtc-cu12==12.5.82
#  + nvidia-cuda-nvrtc-cu12==12.4.127
#  - nvidia-cuda-runtime-cu12==12.5.82
#  + nvidia-cuda-runtime-cu12==12.4.127
#  - nvidia-cudnn-cu12==9.3.0.75
#  + nvidia-cudnn-cu12==9.1.0.70
#  - nvidia-cufft-cu12==11.2.3.61
#  + nvidia-cufft-cu12==11.2.1.3
#  - nvidia-curand-cu12==10.3.6.82
#  + nvidia-curand-cu12==10.3.5.147
#  - nvidia-cusolver-cu12==11.6.3.83
#  + nvidia-cusolver-cu12==11.6.1.9
#  - nvidia-cusparse-cu12==12.5.1.3
#  + nvidia-cusparse-cu12==12.3.1.170
#  - nvidia-nvjitlink-cu12==12.5.82
#  + nvidia-nvjitlink-cu12==12.4.127
#  + opacus==1.5.4
#  - pandas==2.3.0
#  + pandas==2.2.3
#  + paramiko==3.5.1
#  + phik==0.12.4
#  - plotly==5.24.1
#  + plotly==6.1.2
#  - protobuf==5.29.5
#  + protobuf==6.31.1
#  - psutil==7.0.0
#  + psutil==5.9.8
#  + pynacl==1.5.0
#  + s3fs==2025.3.0
#  + s3transfer==0.11.3
#  - scikit-learn==1.6.1
#  + scikit-learn==1.7.0
#  - setuptools==75.2.0
#  + setuptools==80.9.0
#  + sshtunnel==0.4.0
#  + xgrammar==0.1.19
#  + xlsxwriter==3.2.3

# %%
pip install -U 'mostlyai[local]'
# Out:
# Requirement already satisfied: mostlyai[local] in /usr/local/lib/python3.11/dist-packages (4.7.3)
# Requirement already satisfied: duckdb>=1.2.1 in /usr/local/lib/python3.11/dist-packages (from mostlyai[local]) (1.3.0)
# Requirement already satisfied: environs>=9.5.0 in /usr/local/lib/python3.11/dist-packages (from mostlyai[local]) (14.2.0)
# Requirement already satisfied: greenlet>=3.1.1 in /usr/local/lib/python3.11/dist-packages (from mostlyai[local]) (3.2.3)
# Requirement already satisfied: gunicorn>=23.0.0 in /usr/local/lib/python3.11/dist-packages (from mostlyai[local]) (23.0.0)
# Requirement already satisfied: httpx>=0.25.0 in /usr/local/lib/python3.11/dist-packages (from mostlyai[local]) (0.28.1)
# Requirement already satisfied: ipywidgets>=8.1.0 in /usr/local/lib/python3.11/dist-packages (from mostlyai[local]) (8.1.7)
# Requirement already satisfied: pandas>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from mostlyai[local]) (2.2.3)
# Requirement already satisfied: psutil>=5.9.5 in /usr/local/lib/python3.11/dist-packages (from mostlyai[local]) (5.9.8)
# Requirement already satisfied: pyarrow>=16.0.0 in /usr/local/lib/python3.11/dist-packages (from mostlyai[local]) (20.0.0)
# Requirement already satisfied: pycryptodomex>=3.10.0 in /usr/local/lib/python3.11/dist-packages (from mostlyai[local]) (3.23.0)
# Requirement already satisfied: pydantic<3,>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from mostlyai[local]) (2.11.5)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.11/dist-packages (from mostlyai[local]) (2.32.3)
# Requirement already satisfied: rich>=13.7.0 in /usr/local/lib/python3.11/dist-packages (from mostlyai[local]) (14.0.0)
# Requirement already satisfied: schema>=0.7.5 in /usr/local/lib/python3.11/dist-packages (from mostlyai[local]) (0.7.7)
# Requirement already satisfied: semantic-version>=2.10.0 in /usr/local/lib/python3.11/dist-packages (from mostlyai[local]) (2.10.0)
# Requirement already satisfied: smart-open>=6.0.0 in /usr/local/lib/python3.11/dist-packages (from mostlyai[local]) (7.1.0)
# Requirement already satisfied: sqlparse>=0.5.3 in /usr/local/lib/python3.11/dist-packages (from mostlyai[local]) (0.5.3)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from mostlyai[local]) (0.16.0)
# Requirement already satisfied: xxhash>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from mostlyai[local]) (3.5.0)
# Requirement already satisfied: adlfs>=2023.4.0 in /usr/local/lib/python3.11/dist-packages (from mostlyai[local]) (2024.12.0)
# Requirement already satisfied: azure-storage-blob>=12.16.0 in /usr/local/lib/python3.11/dist-packages (from mostlyai[local]) (12.25.1)
# Requirement already satisfied: cloudpathlib>=0.17.0 in /usr/local/lib/python3.11/dist-packages (from cloudpathlib[azure,gs,s3]>=0.17.0; extra == "local"->mostlyai[local]) (0.21.1)
# Requirement already satisfied: fastapi<0.116,>=0.115.6 in /usr/local/lib/python3.11/dist-packages (from mostlyai[local]) (0.115.12)
# Requirement already satisfied: filelock>=3.16.1 in /usr/local/lib/python3.11/dist-packages (from mostlyai[local]) (3.18.0)
# Requirement already satisfied: gcsfs>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from mostlyai[local]) (2025.3.0)
# Requirement already satisfied: joblib>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from mostlyai[local]) (1.5.1)
# Requirement already satisfied: mostlyai-engine==1.4.3 in /usr/local/lib/python3.11/dist-packages (from mostlyai[local]) (1.4.3)
# Requirement already satisfied: mostlyai-qa==1.9.7 in /usr/local/lib/python3.11/dist-packages (from mostlyai[local]) (1.9.7)
# Requirement already satisfied: networkx<4,>=3.0 in /usr/local/lib/python3.11/dist-packages (from mostlyai[local]) (3.5)
# Requirement already satisfied: openpyxl>=3.1.5 in /usr/local/lib/python3.11/dist-packages (from mostlyai[local]) (3.1.5)
# Requirement already satisfied: python-multipart>=0.0.20 in /usr/local/lib/python3.11/dist-packages (from mostlyai[local]) (0.0.20)
# Requirement already satisfied: s3fs>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from mostlyai[local]) (2025.3.0)
# Requirement already satisfied: sqlalchemy>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from mostlyai[local]) (2.0.41)
# Requirement already satisfied: sshtunnel<0.5,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from mostlyai[local]) (0.4.0)
# Requirement already satisfied: torch<2.6.1,>=2.6.0 in /usr/local/lib/python3.11/dist-packages (from mostlyai[local]) (2.6.0+cu124)
# Requirement already satisfied: torchaudio<2.6.1,>=2.6.0 in /usr/local/lib/python3.11/dist-packages (from mostlyai[local]) (2.6.0+cu124)
# Requirement already satisfied: torchvision<0.21.1,>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from mostlyai[local]) (0.21.0+cu124)
# Requirement already satisfied: uvicorn<0.35,>=0.34.0 in /usr/local/lib/python3.11/dist-packages (from mostlyai[local]) (0.34.3)
# Requirement already satisfied: xlsxwriter<4,>=3.1.9 in /usr/local/lib/python3.11/dist-packages (from mostlyai[local]) (3.2.3)
# Requirement already satisfied: accelerate>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from mostlyai-engine==1.4.3->mostlyai[local]) (1.7.0)
# Requirement already satisfied: datasets>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from mostlyai-engine==1.4.3->mostlyai[local]) (3.6.0)
# Requirement already satisfied: huggingface-hub>=0.30.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub[hf-xet]>=0.30.2->mostlyai-engine==1.4.3->mostlyai[local]) (0.32.4)
# Requirement already satisfied: json-repair>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from mostlyai-engine==1.4.3->mostlyai[local]) (0.46.2)
# Requirement already satisfied: numpy>=1.26.3 in /usr/local/lib/python3.11/dist-packages (from mostlyai-engine==1.4.3->mostlyai[local]) (2.2.6)
# Requirement already satisfied: opacus>=1.5.2 in /usr/local/lib/python3.11/dist-packages (from mostlyai-engine==1.4.3->mostlyai[local]) (1.5.4)
# Requirement already satisfied: peft>=0.12.0 in /usr/local/lib/python3.11/dist-packages (from mostlyai-engine==1.4.3->mostlyai[local]) (0.15.2)
# Requirement already satisfied: setuptools>=77.0.3 in /usr/local/lib/python3.11/dist-packages (from mostlyai-engine==1.4.3->mostlyai[local]) (80.9.0)
# Requirement already satisfied: tokenizers>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from mostlyai-engine==1.4.3->mostlyai[local]) (0.21.1)
# Requirement already satisfied: transformers>=4.51.0 in /usr/local/lib/python3.11/dist-packages (from mostlyai-engine==1.4.3->mostlyai[local]) (4.52.4)
# Requirement already satisfied: xgrammar>=0.1.18 in /usr/local/lib/python3.11/dist-packages (from mostlyai-engine==1.4.3->mostlyai[local]) (0.1.19)
# Requirement already satisfied: jinja2>=3.1.5 in /usr/local/lib/python3.11/dist-packages (from mostlyai-qa==1.9.7->mostlyai[local]) (3.1.6)
# Requirement already satisfied: model2vec>=0.4.1 in /usr/local/lib/python3.11/dist-packages (from mostlyai-qa==1.9.7->mostlyai[local]) (0.6.0)
# Requirement already satisfied: phik>=0.12.4 in /usr/local/lib/python3.11/dist-packages (from mostlyai-qa==1.9.7->mostlyai[local]) (0.12.4)
# Requirement already satisfied: plotly>=6.0.0 in /usr/local/lib/python3.11/dist-packages (from mostlyai-qa==1.9.7->mostlyai[local]) (6.1.2)
# Requirement already satisfied: scikit-learn>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from mostlyai-qa==1.9.7->mostlyai[local]) (1.7.0)
# Requirement already satisfied: scipy>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from mostlyai-qa==1.9.7->mostlyai[local]) (1.15.3)
# Requirement already satisfied: azure-core<2.0.0,>=1.28.0 in /usr/local/lib/python3.11/dist-packages (from adlfs>=2023.4.0->mostlyai[local]) (1.34.0)
# Requirement already satisfied: azure-datalake-store<0.1,>=0.0.53 in /usr/local/lib/python3.11/dist-packages (from adlfs>=2023.4.0->mostlyai[local]) (0.0.53)
# Requirement already satisfied: azure-identity in /usr/local/lib/python3.11/dist-packages (from adlfs>=2023.4.0->mostlyai[local]) (1.23.0)
# Requirement already satisfied: fsspec>=2023.12.0 in /usr/local/lib/python3.11/dist-packages (from adlfs>=2023.4.0->mostlyai[local]) (2025.3.0)
# Requirement already satisfied: aiohttp>=3.7.0 in /usr/local/lib/python3.11/dist-packages (from adlfs>=2023.4.0->mostlyai[local]) (3.12.9)
# Requirement already satisfied: cryptography>=2.1.4 in /usr/local/lib/python3.11/dist-packages (from azure-storage-blob>=12.16.0->mostlyai[local]) (45.0.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from azure-storage-blob>=12.16.0->mostlyai[local]) (4.14.0)
# Requirement already satisfied: isodate>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from azure-storage-blob>=12.16.0->mostlyai[local]) (0.7.2)
# Requirement already satisfied: azure-storage-file-datalake>=12 in /usr/local/lib/python3.11/dist-packages (from cloudpathlib[azure,gs,s3]>=0.17.0; extra == "local"->mostlyai[local]) (12.20.0)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.11/dist-packages (from cloudpathlib[azure,gs,s3]>=0.17.0; extra == "local"->mostlyai[local]) (3.1.0)
# Requirement already satisfied: boto3>=1.34.0 in /usr/local/lib/python3.11/dist-packages (from cloudpathlib[azure,gs,s3]>=0.17.0; extra == "local"->mostlyai[local]) (1.37.3)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.11/dist-packages (from environs>=9.5.0->mostlyai[local]) (1.1.0)
# Requirement already satisfied: marshmallow>=3.18.0 in /usr/local/lib/python3.11/dist-packages (from environs>=9.5.0->mostlyai[local]) (4.0.0)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /usr/local/lib/python3.11/dist-packages (from fastapi<0.116,>=0.115.6->mostlyai[local]) (0.46.2)
# Requirement already satisfied: decorator>4.1.2 in /usr/local/lib/python3.11/dist-packages (from gcsfs>=2023.1.0->mostlyai[local]) (5.2.1)
# Requirement already satisfied: google-auth>=1.2 in /usr/local/lib/python3.11/dist-packages (from gcsfs>=2023.1.0->mostlyai[local]) (2.40.3)
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.11/dist-packages (from gcsfs>=2023.1.0->mostlyai[local]) (1.2.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from gunicorn>=23.0.0->mostlyai[local]) (25.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.0->mostlyai[local]) (4.9.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.0->mostlyai[local]) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.0->mostlyai[local]) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.11/dist-packages (from httpx>=0.25.0->mostlyai[local]) (3.10)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.11/dist-packages (from httpcore==1.*->httpx>=0.25.0->mostlyai[local]) (0.16.0)
# Requirement already satisfied: comm>=0.1.3 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=8.1.0->mostlyai[local]) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=8.1.0->mostlyai[local]) (9.3.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=8.1.0->mostlyai[local]) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=8.1.0->mostlyai[local]) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=8.1.0->mostlyai[local]) (3.0.15)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.11/dist-packages (from openpyxl>=3.1.5->mostlyai[local]) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->mostlyai[local]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->mostlyai[local]) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.0.0->mostlyai[local]) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2.4.2->mostlyai[local]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2.4.2->mostlyai[local]) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=2.4.2->mostlyai[local]) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->mostlyai[local]) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.31.0->mostlyai[local]) (2.4.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.7.0->mostlyai[local]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=13.7.0->mostlyai[local]) (2.19.1)
# Requirement already satisfied: aiobotocore<3.0.0,>=2.5.4 in /usr/local/lib/python3.11/dist-packages (from s3fs>=2023.1.0->mostlyai[local]) (2.22.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open>=6.0.0->mostlyai[local]) (1.17.2)
# Requirement already satisfied: azure-common in /usr/local/lib/python3.11/dist-packages (from smart-open[azure,gcs,s3]>=6.3.0; extra == "local"->mostlyai[local]) (1.1.28)
# Requirement already satisfied: paramiko>=2.7.2 in /usr/local/lib/python3.11/dist-packages (from sshtunnel<0.5,>=0.4.0->mostlyai[local]) (3.5.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<2.6.1,>=2.6.0->mostlyai[local]) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<2.6.1,>=2.6.0->mostlyai[local]) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<2.6.1,>=2.6.0->mostlyai[local]) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch<2.6.1,>=2.6.0->mostlyai[local]) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch<2.6.1,>=2.6.0->mostlyai[local]) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch<2.6.1,>=2.6.0->mostlyai[local]) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch<2.6.1,>=2.6.0->mostlyai[local]) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch<2.6.1,>=2.6.0->mostlyai[local]) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch<2.6.1,>=2.6.0->mostlyai[local]) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<2.6.1,>=2.6.0->mostlyai[local]) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<2.6.1,>=2.6.0->mostlyai[local]) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<2.6.1,>=2.6.0->mostlyai[local]) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<2.6.1,>=2.6.0->mostlyai[local]) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<2.6.1,>=2.6.0->mostlyai[local]) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<2.6.1,>=2.6.0->mostlyai[local]) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<2.6.1,>=2.6.0->mostlyai[local]) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision<0.21.1,>=0.21.0->mostlyai[local]) (11.2.1)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.9.0->mostlyai[local]) (8.2.1)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer>=0.9.0->mostlyai[local]) (1.5.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from accelerate>=1.5.0->mostlyai-engine==1.4.3->mostlyai[local]) (6.0.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from accelerate>=1.5.0->mostlyai-engine==1.4.3->mostlyai[local]) (0.5.3)
# Requirement already satisfied: aioitertools<1.0.0,>=0.5.1 in /usr/local/lib/python3.11/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2023.1.0->mostlyai[local]) (0.12.0)
# Requirement already satisfied: botocore<1.37.4,>=1.37.2 in /usr/local/lib/python3.11/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2023.1.0->mostlyai[local]) (1.37.3)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2023.1.0->mostlyai[local]) (1.0.1)
# Requirement already satisfied: multidict<7.0.0,>=6.0.0 in /usr/local/lib/python3.11/dist-packages (from aiobotocore<3.0.0,>=2.5.4->s3fs>=2023.1.0->mostlyai[local]) (6.4.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.7.0->adlfs>=2023.4.0->mostlyai[local]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.7.0->adlfs>=2023.4.0->mostlyai[local]) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.7.0->adlfs>=2023.4.0->mostlyai[local]) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.7.0->adlfs>=2023.4.0->mostlyai[local]) (1.6.2)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.7.0->adlfs>=2023.4.0->mostlyai[local]) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp>=3.7.0->adlfs>=2023.4.0->mostlyai[local]) (1.20.0)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from azure-core<2.0.0,>=1.28.0->adlfs>=2023.4.0->mostlyai[local]) (1.17.0)
# Requirement already satisfied: cffi in /usr/local/lib/python3.11/dist-packages (from azure-datalake-store<0.1,>=0.0.53->adlfs>=2023.4.0->mostlyai[local]) (1.17.1)
# Requirement already satisfied: msal<2,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from azure-datalake-store<0.1,>=0.0.53->adlfs>=2023.4.0->mostlyai[local]) (1.32.3)
# Requirement already satisfied: s3transfer<0.12.0,>=0.11.0 in /usr/local/lib/python3.11/dist-packages (from boto3>=1.34.0->cloudpathlib[azure,gs,s3]>=0.17.0; extra == "local"->mostlyai[local]) (0.11.3)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=3.0.0->mostlyai-engine==1.4.3->mostlyai[local]) (0.3.8)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets>=3.0.0->mostlyai-engine==1.4.3->mostlyai[local]) (4.67.1)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets>=3.0.0->mostlyai-engine==1.4.3->mostlyai[local]) (0.70.16)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.2->gcsfs>=2023.1.0->mostlyai[local]) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.2->gcsfs>=2023.1.0->mostlyai[local]) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.2->gcsfs>=2023.1.0->mostlyai[local]) (4.9.1)
# Requirement already satisfied: google-api-core<3.0.0dev,>=2.15.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage->cloudpathlib[azure,gs,s3]>=0.17.0; extra == "local"->mostlyai[local]) (2.25.0)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage->cloudpathlib[azure,gs,s3]>=0.17.0; extra == "local"->mostlyai[local]) (2.4.3)
# Requirement already satisfied: google-resumable-media>=2.7.2 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage->cloudpathlib[azure,gs,s3]>=0.17.0; extra == "local"->mostlyai[local]) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage->cloudpathlib[azure,gs,s3]>=0.17.0; extra == "local"->mostlyai[local]) (1.7.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.30.2->huggingface-hub[hf-xet]>=0.30.2->mostlyai-engine==1.4.3->mostlyai[local]) (1.1.3)
# Requirement already satisfied: ipython-pygments-lexers in /usr/local/lib/python3.11/dist-packages (from ipython>=6.1.0->ipywidgets>=8.1.0->mostlyai[local]) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from ipython>=6.1.0->ipywidgets>=8.1.0->mostlyai[local]) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython>=6.1.0->ipywidgets>=8.1.0->mostlyai[local]) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython>=6.1.0->ipywidgets>=8.1.0->mostlyai[local]) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /usr/local/lib/python3.11/dist-packages (from ipython>=6.1.0->ipywidgets>=8.1.0->mostlyai[local]) (3.0.51)
# Requirement already satisfied: stack_data in /usr/local/lib/python3.11/dist-packages (from ipython>=6.1.0->ipywidgets>=8.1.0->mostlyai[local]) (0.6.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=3.1.5->mostlyai-qa==1.9.7->mostlyai[local]) (3.0.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=13.7.0->mostlyai[local]) (0.1.2)
# Requirement already satisfied: opt-einsum>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from opacus>=1.5.2->mostlyai-engine==1.4.3->mostlyai[local]) (3.4.0)
# Requirement already satisfied: bcrypt>=3.2 in /usr/local/lib/python3.11/dist-packages (from paramiko>=2.7.2->sshtunnel<0.5,>=0.4.0->mostlyai[local]) (4.3.0)
# Requirement already satisfied: pynacl>=1.5 in /usr/local/lib/python3.11/dist-packages (from paramiko>=2.7.2->sshtunnel<0.5,>=0.4.0->mostlyai[local]) (1.5.0)
# Requirement already satisfied: matplotlib>=2.2.3 in /usr/local/lib/python3.11/dist-packages (from phik>=0.12.4->mostlyai-qa==1.9.7->mostlyai[local]) (3.10.3)
# Requirement already satisfied: narwhals>=1.15.1 in /usr/local/lib/python3.11/dist-packages (from plotly>=6.0.0->mostlyai-qa==1.9.7->mostlyai[local]) (1.41.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.4.0->mostlyai-qa==1.9.7->mostlyai[local]) (3.6.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio->httpx>=0.25.0->mostlyai[local]) (1.3.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.51.0->mostlyai-engine==1.4.3->mostlyai[local]) (2024.11.6)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (from xgrammar>=0.1.18->mostlyai-engine==1.4.3->mostlyai[local]) (0.2.0)
# Requirement already satisfied: tiktoken in /usr/local/lib/python3.11/dist-packages (from xgrammar>=0.1.18->mostlyai-engine==1.4.3->mostlyai[local]) (0.9.0)
# Requirement already satisfied: ninja in /usr/local/lib/python3.11/dist-packages (from xgrammar>=0.1.18->mostlyai-engine==1.4.3->mostlyai[local]) (1.11.1.4)
# Requirement already satisfied: msal-extensions>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from azure-identity->adlfs>=2023.4.0->mostlyai[local]) (1.3.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib->gcsfs>=2023.1.0->mostlyai[local]) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi->azure-datalake-store<0.1,>=0.0.53->adlfs>=2023.4.0->mostlyai[local]) (2.22)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->cloudpathlib[azure,gs,s3]>=0.17.0; extra == "local"->mostlyai[local]) (1.70.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->cloudpathlib[azure,gs,s3]>=0.17.0; extra == "local"->mostlyai[local]) (6.31.1)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->cloudpathlib[azure,gs,s3]>=0.17.0; extra == "local"->mostlyai[local]) (1.26.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=8.1.0->mostlyai[local]) (0.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.2.3->phik>=0.12.4->mostlyai-qa==1.9.7->mostlyai[local]) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.2.3->phik>=0.12.4->mostlyai-qa==1.9.7->mostlyai[local]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.2.3->phik>=0.12.4->mostlyai-qa==1.9.7->mostlyai[local]) (4.58.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.2.3->phik>=0.12.4->mostlyai-qa==1.9.7->mostlyai[local]) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.2.3->phik>=0.12.4->mostlyai-qa==1.9.7->mostlyai[local]) (3.2.3)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from PyJWT[crypto]<3,>=1.0.0->msal<2,>=1.16.0->azure-datalake-store<0.1,>=0.0.53->adlfs>=2023.4.0->mostlyai[local]) (2.10.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=8.1.0->mostlyai[local]) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=8.1.0->mostlyai[local]) (0.2.13)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.2->gcsfs>=2023.1.0->mostlyai[local]) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs>=2023.1.0->mostlyai[local]) (3.2.2)
# Requirement already satisfied: executing>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from stack_data->ipython>=6.1.0->ipywidgets>=8.1.0->mostlyai[local]) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from stack_data->ipython>=6.1.0->ipywidgets>=8.1.0->mostlyai[local]) (3.0.0)
# Requirement already satisfied: pure-eval in /usr/local/lib/python3.11/dist-packages (from stack_data->ipython>=6.1.0->ipywidgets>=8.1.0->mostlyai[local]) (0.2.3)

# %% [markdown]
# ## Load Original Data
#
# Fetch some original data that will be used for training the generator.

# %%
import pandas as pd

# fetch some original data
repo_url = "https://github.com/mostly-ai/public-demo-data/raw/refs/heads/dev"
df_original = pd.read_csv(f"{repo_url}/census/census.csv.gz")
df_original
# Out:
#        age         workclass  fnlwgt  education  education_num  \
# 0       39         State-gov   77516  Bachelors             13
# 1       50  Self-emp-not-inc   83311  Bachelors             13
# 2       38           Private  215646    HS-grad              9
# 3       53           Private  234721       11th              7
# 4       28           Private  338409  Bachelors             13
# ...    ...               ...     ...        ...            ...
# 48837   39           Private  215419  Bachelors             13
# 48838   64                 ?  321403    HS-grad              9
# 48839   38           Private  374983  Bachelors             13
# 48840   44           Private   83891  Bachelors             13
# 48841   35      Self-emp-inc  182148  Bachelors             13
#
#            marital_status         occupation    relationship  \
# 0           Never-married       Adm-clerical   Not-in-family
# 1      Married-civ-spouse    Exec-managerial         Husband
# 2                Divorced  Handlers-cleaners   Not-in-family
# 3      Married-civ-spouse  Handlers-cleaners         Husband
# 4      Married-civ-spouse     Prof-specialty            Wife
# ...                   ...                ...             ...
# 48837            Divorced     Prof-specialty   Not-in-family
# 48838             Widowed                  ?  Other-relative
# 48839  Married-civ-spouse     Prof-specialty         Husband
# 48840            Divorced       Adm-clerical       Own-child
# 48841  Married-civ-spouse    Exec-managerial         Husband
#
#                      race     sex  capital_gain  capital_loss  hours_per_week  \
# 0                   White    Male          2174             0              40
# 1                   White    Male             0             0              13
# 2                   White    Male             0             0              40
# 3                   Black    Male             0             0              40
# 4                   Black  Female             0             0              40
# ...                   ...     ...           ...           ...             ...
# 48837               White  Female             0             0              36
# 48838               Black    Male             0             0              40
# 48839               White    Male             0             0              50
# 48840  Asian-Pac-Islander    Male          5455             0              40
# 48841               White    Male             0             0              60
#
#       native_country income
# 0      United-States  <=50K
# 1      United-States  <=50K
# 2      United-States  <=50K
# 3      United-States  <=50K
# 4               Cuba  <=50K
# ...              ...    ...
# 48837  United-States  <=50K
# 48838  United-States  <=50K
# 48839  United-States  <=50K
# 48840  United-States  <=50K
# 48841  United-States   >50K
#
# [48842 rows x 15 columns]

# %% [markdown]
# ## Initialize the SDK

# %%
from mostlyai.sdk import MostlyAI

# initialize SDK
mostly = MostlyAI(local="true")
# Out:
# ╭──────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ LOCAL mode requires additional packages to be installed. Run `pip install -U 'mostlyai[local]'`. │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/mostlyai/sdk/client/_utils.py in check_local_mode_available()
#      56     try:
# ---> 57         from mostlyai.sdk._local.server import LocalServer  # noqa
#      58         from mostlyai import qa  # noqa
#
# /usr/local/lib/python3.11/dist-packages/mostlyai/sdk/_local/server.py in <module>
#      26
# ---> 27 from mostlyai.sdk._local.routes import Routes
#      28
#
# /usr/local/lib/python3.11/dist-packages/mostlyai/sdk/_local/routes.py in <module>
#      32 from mostlyai.sdk._local import connectors, generators, synthetic_datasets
# ---> 33 from mostlyai.sdk._local.execution.jobs import execute_probing_job
#      34 from mostlyai.sdk._local.generators import create_generator as create_generator_model
#
# /usr/local/lib/python3.11/dist-packages/mostlyai/sdk/_local/execution/jobs.py in <module>
#      34 from mostlyai.sdk._local.execution.step_analyze_training_data import execute_step_analyze_training_data
# ---> 35 from mostlyai.sdk._local.execution.step_create_data_report import execute_step_create_data_report
#      36 from mostlyai.sdk._local.execution.step_create_model_report import (
#
# /usr/local/lib/python3.11/dist-packages/mostlyai/sdk/_local/execution/step_create_data_report.py in <module>
#      17
# ---> 18 from mostlyai.sdk._local.execution.step_create_model_report import create_report
#      19 from mostlyai.sdk.domain import Generator, ModelType, StepCode
#
# /usr/local/lib/python3.11/dist-packages/mostlyai/sdk/_local/execution/step_create_model_report.py in <module>
#      25
# ---> 26 from mostlyai import qa
#      27 from mostlyai.engine._workspace import Workspace
#
# /usr/local/lib/python3.11/dist-packages/mostlyai/qa/__init__.py in <module>
#      22 from mostlyai.qa.random_state import set_random_state
# ---> 23 from mostlyai.qa.reporting import report
#      24 from mostlyai.qa.reporting_from_statistics import report_from_statistics
#
# /usr/local/lib/python3.11/dist-packages/mostlyai/qa/reporting.py in <module>
#      22
# ---> 23 from mostlyai.qa import _distances, _html_report, _similarity
#      24 from mostlyai.qa._accuracy import (
#
# /usr/local/lib/python3.11/dist-packages/mostlyai/qa/_distances.py in <module>
#      21 from plotly import graph_objs as go
# ---> 22 from sklearn.cluster import SpectralClustering
#      23 from sklearn.neighbors import NearestNeighbors
#
# /usr/local/lib/python3.11/dist-packages/sklearn/__init__.py in <module>
#      72 )
# ---> 73 from .base import clone  # noqa: E402
#      74 from .utils._show_versions import show_versions  # noqa: E402
#
# /usr/local/lib/python3.11/dist-packages/sklearn/base.py in <module>
#      19 from .utils._metadata_requests import _MetadataRequester, _routing_enabled
# ---> 20 from .utils._missing import is_scalar_nan
#      21 from .utils._param_validation import validate_parameter_constraints
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/__init__.py in <module>
#       8 from ._bunch import Bunch
# ----> 9 from ._chunking import gen_batches, gen_even_slices
#      10
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_chunking.py in <module>
#      10 from .._config import get_config
# ---> 11 from ._param_validation import Interval, validate_params
#      12
#
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/_param_validation.py in <module>
#      13 import numpy as np
# ---> 14 from scipy.sparse import csr_matrix, issparse
#      15
#
# /usr/local/lib/python3.11/dist-packages/scipy/sparse/__init__.py in <module>
#     299
# --> 300 from ._base import *
#     301 from ._csr import *
#
# /usr/local/lib/python3.11/dist-packages/scipy/sparse/_base.py in <module>
#       4
# ----> 5 from ._sputils import (asmatrix, check_reshape_kwargs, check_shape,
#       6                        get_sum_dtype, isdense, isscalarlike,
#
# /usr/local/lib/python3.11/dist-packages/scipy/sparse/_sputils.py in <module>
#       9 import scipy.sparse as sp
# ---> 10 from scipy._lib._util import np_long, np_ulong
#      11
#
# /usr/local/lib/python3.11/dist-packages/scipy/_lib/_util.py in <module>
#      12 import numpy as np
# ---> 13 from scipy._lib._array_api import array_namespace, is_numpy, xp_size
#      14 from scipy._lib._docscrape import FunctionDoc, Parameter
#
# /usr/local/lib/python3.11/dist-packages/scipy/_lib/_array_api.py in <module>
#      17 from scipy._lib import array_api_compat
# ---> 18 from scipy._lib.array_api_compat import (
#      19     is_array_api_obj,
#
# /usr/local/lib/python3.11/dist-packages/scipy/_lib/array_api_compat/numpy/__init__.py in <module>
# ----> 1 from numpy import * # noqa: F403
#       2
#       3 # from numpy import * doesn't overwrite these builtin names
#
# /usr/local/lib/python3.11/dist-packages/numpy/__init__.py in __getattr__(attr)
#     375         elif attr == "core":
# --> 376             import numpy.core as core
#     377             return core
#
# /usr/local/lib/python3.11/dist-packages/numpy/strings/__init__.py in <module>
# ----> 1 from numpy._core.strings import __all__, __doc__
#       2 from numpy._core.strings import *
#
# /usr/local/lib/python3.11/dist-packages/numpy/_core/strings.py in <module>
#      13 from numpy._core.overrides import set_module
# ---> 14 from numpy._core.umath import (
#      15     isalpha,
#
# ImportError: cannot import name '_center' from 'numpy._core.umath' (/usr/local/lib/python3.11/dist-packages/numpy/_core/umath.py)
#
# During handling of the above exception, another exception occurred:
#
# APIError                                  Traceback (most recent call last)
# <ipython-input-10-95e8d6b3a8e1> in <cell line: 0>()
#       2
#       3 # initialize SDK
# ----> 4 mostly = MostlyAI(local="true")
#
# /usr/local/lib/python3.11/dist-packages/mostlyai/sdk/client/api.py in __init__(self, base_url, api_key, local, local_dir, local_port, timeout, ssl_verify, quiet)
#     163
#     164         if mode == "LOCAL":
# --> 165             check_local_mode_available()
#     166             from mostlyai.sdk._local.server import LocalServer  # noqa
#     167
#
# /usr/local/lib/python3.11/dist-packages/mostlyai/sdk/client/_utils.py in check_local_mode_available()
#      60         return
#      61     except ImportError:
# ---> 62         raise APIError(
#      63             "LOCAL mode requires additional packages to be installed. Run `pip install -U 'mostlyai[local]'`."
#      64         )
#
# APIError: LOCAL mode requires additional packages to be installed. Run `pip install -U 'mostlyai[local]'`.

# %% [markdown]
# ## Train a Generator
#
# Train a synthetic data generator.

# %%
# train a generator, with defaults
g = mostly.train(data=df_original)

# %% [markdown]
# ## Generate Synthetic Data
#
# Probe for a single synthetic sample.

# %%
mostly.probe(g)

# %% [markdown]
# Probe the trained generator for 100 representative synthetic samples.

# %%
mostly.probe(g, size=100)

# %% [markdown]
# Generate a larger scale representative synthetic dataset.

# %%
sd = mostly.generate(g, size=1_000_000)
df_synthetic = sd.data()
df_synthetic

# %% [markdown]
# Conditionally generate 1000 records of 70y old male citizens.

# %%
df_seed = pd.DataFrame(
    {
        "age": [70] * 1_000,
        "sex": ["Male"] * 1_000,
    }
)
# conditionally probe, based on provided seed
df_samples = mostly.probe(g, seed=df_seed)
df_samples

# %% [markdown]
# ## Quality Assurance
#
# Inspect the automated Quality Assurance report, to learn about the accuracy, similarity and novelty of the generated synthetic samples.

# %%
# display the quality assurance report
g.reports(display=True)

# %% [markdown]
# ## Export Generator
#
# Export the generator for further sharing with other SDK users. Plus, you can import zipped generators also to a MOSTLY AI platform.

# %%
# export the generator
g.export_to_file("census-generator.zip")

# %% [markdown]
# ## Advanced Options
#
# Several configuration parameters are available that allow fine-grained control over the training of the generator. See `?mostly.train` for further examples. See [GeneratorConfig](https://mostly-ai.github.io/mostlyai/api_domain/#mostlyai.sdk.domain.GeneratorConfig) as well as [SourceTableConfig](https://mostly-ai.github.io/mostlyai/api_domain/#mostlyai.sdk.domain.SourceTableConfig) for all available configuration settings.
#
# The following example trains e.g. a differentially private generator, for a maximum of 2 minutes.

# %%
g = mostly.train(
    config={
        "name": "Census",  # name of the generator
        "tables": [
            {
                "name": "census",
                "data": df_original,
                "tabular_model_configuration": {  # tabular model configuration (optional)
                    "max_training_time": 2,  # - limit training time (in minutes)
                    # model, max_epochs,,..       # further model configurations (optional)
                    "differential_privacy": {  # differential privacy configuration (optional)
                        "max_epsilon": 5.0,  # - max epsilon value, used as stopping criterion
                        "delta": 1e-5,  # - delta value for differentially private training (DP-SGD)
                        "noise_multiplier": 1.5,  # - noise level for privacy for DP-SGD
                        "max_grad_norm": 1.0,  # - maximum norm of the per-sample gradients for DP-SGD
                        "value_protection_epsilon": 2.0,  # - DP epsilon for determining value ranges / data domains
                    },
                },
                # columns, keys, compute,..        # further table configurations (optional)
            }
        ],
    },
    start=False,  # start training immediately (default: True)
    wait=False,  # wait for completion (default: True)
)

# %%
# launch training asynchronously
g.training.start()

# %%
# observe training status
g.training.wait()

# %% [markdown]
# ## Conclusion
#
# This tutorial demonstrated the basic usage of the Synthetic Data SDK. You have successfully trained a generator from scratch, given the original data. And you have then used the generator to sample new records, according to your specifications.
#
# See the other tutorials for further exercises.
